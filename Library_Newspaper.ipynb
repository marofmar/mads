# %%
import newspaper

# %%
newspaper.languages()
# Out:
# Your available languages are:
#
# input code		full name
#   fi			  Finnish
#   zh			  Chinese
#   ru			  Russian
#   da			  Danish
#   he			  Hebrew
#   it			  Italian
#   ko			  Korean
#   nb			  Norwegian (Bokmål)
#   de			  German
#   fr			  French
#   en			  English
#   el			  Greek
#   tr			  Turkish
#   nl			  Dutch
#   es			  Spanish
#   ar			  Arabic
#   sv			  Swedish
#   id			  Indonesian
#   hu			  Hungarian
#   vi			  Vietnamese
#   mk			  Macedonian
#   pt			  Portuguese
#   no			  Norwegian

# %%
cnn_paper = newspaper.build('http://cnn.com')
for article in cnn_paper.articles:
    print(article.url)
# Out:
# http://www.cnn.com/2017/09/06/europe/britain-leaked-immigration-paper/index.html
# http://www.cnn.com/2017/08/31/europe/theresa-may-leadership/index.html
# http://www.cnn.com/2017/09/06/europe/ecj-ruling-migrants-hungary-slovakia/index.html
# http://www.cnn.com/2017/09/06/europe/martin-schulz-germany/index.html
# http://www.cnn.com/2017/09/05/world/mafia-kingpin-arrest-uruguay/index.html
# http://www.cnn.com/2017/09/05/europe/pope-colombia-preview/index.html
# http://www.cnn.com/2017/09/05/europe/british-army-national-action/index.html
# http://www.cnn.com/2017/09/05/europe/uk-royals-photo-controversy/index.html
# http://www.cnn.com/2017/09/05/europe/denmark-kim-wall-death-hearing/index.html
# http://www.cnn.com/2017/08/31/europe/german-election-guide-trnd/index.html
# http://www.cnn.com/2017/09/05/europe/meghan-markle-vanity-fair/index.html
# http://www.cnn.com/2017/09/05/europe/us-diplomats-putin/index.html
# http://www.cnn.com/2017/09/04/europe/turkey-germany-populism/index.html
# ...

# %%
for category in cnn_paper.category_urls():
    print(category)
# Out:
# http://cnn.com
# http://cnn.com/style
# http://cnn.com/specials
# http://cnn.com/africa
# http://cnn.com/opinions
# http://cnn.com/collection
# http://cnn.com/politics
# http://cnn.com/entertainment
# http://cnn.com/travel
# http://cnn.com/middle-east
# http://cnn.com/weather
# http://cnnpressroom.blogs.cnn.com
# http://money.cnn.com
# http://cnn.com/europe
# http://commercial.cnn.com
# http://cnn.com/us
# http://cnn.com/sport
# http://cnn.com/msa
# http://cnn.com/more
# http://cnn.com/asia
# http://cnn.com/china
# http://cnn.com/americas
# http://go.cnn.com
# http://cnn.com/videos
# http://cnn.com/health
# http://cnn.com/regions
# http://cnn.com/vr
# http://cnn.com/transcripts

# %%
article = cnn_paper.articles[0]

# %%
article.download()

# %%
article.html
# Out:
# '<!DOCTYPE html><html class="no-js"><head><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"><meta charset="utf-8"><meta content="text/html" http-equiv="Content-Type"><meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0"><script type="text/javascript" async="false">(function(win, doc) {var bannerElement;win.enableSmartBannerTracking = false;if (typeof navigator.userAgent === \'string\' && navigator.userAgent.search(/(iPhone|iPad|iPod);/) !== -1 &&typeof doc.cookie === \'string\' && doc.cookie.search(/(^|;)\\s*CNNtosAgreed=[^;]+/) !== -1) {bannerElement = doc.createElement(\'meta\');win.enableSmartBannerTracking = true;bannerElement.name = "apple-itunes-app";bannerElement.content = "app-id=331786748";doc.getElementsByTagName(\'head\')[0].appendChild(bannerElement);}}(window, document));</script><link href="/favicon.ie9.ico" rel="Shortcut Icon" type="image/x-icon"/><link href="//i.cdn.cnn.com/cnn/.e/img/3.0/global/misc/apple-touch-icon.png"
# ...

# %%
article.parse()

# %%
article.authors
# Out:
# ['James Masters']

# %%
article.text
# Out:
# "London (CNN) The UK government has drawn up plans aimed at slashing the levels of migration from the European Union immediately after Brexit, according to a document obtained by the Guardian.\n\nOfficials at the Home Office, the UK government department that has responsibility for immigration, outlined a series of stringent measures aimed at making immigration from the EU harder after Britain leaves the bloc in 2019.\n\nThey include ending the free movement of labor on the day that Britain leaves the EU, and making it harder for lower-skilled workers to enter.\n\nOpponents of Brexit criticized the measures as unnecessarily harsh, and some commentators said they were at odds with the government's stated aim of achieving a transition deal with the EU after Brexit.\n\nBut government ministers said voters expected to see a reduction in immigration.\n\nRead More"

# %%
article.top_image
# Out:
# 'http://i2.cdn.cnn.com/cnnnext/dam/assets/170906095143-uk-border-super-tease.jpg'

# %%
article.movies
# Out:
# []

# %%
article.nlp()

# %%
article.keywords
# Out:
# ['paper',
#  'making',
#  'measures',
#  'uk',
#  'brexit',
#  'leaves',
#  'harder',
#  'leaked',
#  'slash',
#  'aimed',
#  'britain',
#  'eu',
#  'immigration',
#  'migration']

# %%
article.summary
# Out:
# "London (CNN) The UK government has drawn up plans aimed at slashing the levels of migration from the European Union immediately after Brexit, according to a document obtained by the Guardian.\nOfficials at the Home Office, the UK government department that has responsibility for immigration, outlined a series of stringent measures aimed at making immigration from the EU harder after Britain leaves the bloc in 2019.\nThey include ending the free movement of labor on the day that Britain leaves the EU, and making it harder for lower-skilled workers to enter.\nOpponents of Brexit criticized the measures as unnecessarily harsh, and some commentators said they were at odds with the government's stated aim of achieving a transition deal with the EU after Brexit.\nBut government ministers said voters expected to see a reduction in immigration."

# %%
import os

# %%
os.name
# Out:
# 'posix'

# %%
os.environ
# Out:
# environ({'XDG_VTNR': '7', 'XDG_SESSION_ID': 'c2', 'XDG_GREETER_DATA_DIR': '/var/lib/lightdm-data/snu', 'CLUTTER_IM_MODULE': 'xim', 'SESSION': 'ubuntu', 'GPG_AGENT_INFO': '/home/snu/.gnupg/S.gpg-agent:0:1', 'TERM': 'xterm-color', 'VTE_VERSION': '4205', 'XDG_MENU_PREFIX': 'gnome-', 'SHELL': '/bin/bash', 'DERBY_HOME': '/usr/lib/jvm/java-8-oracle/db', 'QT_LINUX_ACCESSIBILITY_ALWAYS_ON': '1', 'WINDOWID': '77594634', 'OLDPWD': '/home/snu', 'UPSTART_SESSION': 'unix:abstract=/com/ubuntu/upstart-session/1000/1628', 'GNOME_KEYRING_CONTROL': '', 'GTK_MODULES': 'gail:atk-bridge:unity-gtk-module', 'USER': 'snu', 'LS_COLORS': 'rs=0:di=01;34:ln=01;36:mh=00:pi=40;33:so=01;35:do=01;35:bd=40;33;01:cd=40;33;01:or=40;31;01:mi=00:su=37;41:sg=30;43:ca=30;41:tw=30;42:ow=34;42:st=37;44:ex=01;32:*.tar=01;31:*.tgz=01;31:*.arc=01;31:*.arj=01;31:*.taz=01;31:*.lha=01;31:*.lz4=01;31:*.lzh=01;31:*.lzma=01;31:*.tlz=01;31:*.txz=01;31:*.tzo=01;31:*.t7z=01;31:*.zip=01;31:*.z=01;31:*.Z=01;31:*.dz=01;31:*.gz=01;31:*.lrz
# ...

# %%
os.environ['PATH']
# Out:
# '/home/snu/anaconda3/bin:/home/snu/anaconda3/bin:/home/snu/bin:/home/snu/.local/bin:/usr/local/cuda-8.0/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin'

# %%
os.getcwd() # return current working directory
# Out:
# '/home/snu/mads'

# %%
ls
# Out:
# [BDE]_0802317.ipynb
# [BDE]_08302017.ipynb
# [BDE]_09062017.ipynb
# [BDP]_170904.ipynb
# call_tkinter.py
# canvas_1.ipynb
# canvas_2.ipynb
# canvas_3.ipynb
# canvas_4.ipynb
# canvas_5.ipynb
# canvas_6.ipynb
# canvas_7.ipynb
# canvas_8.ipynb
# [el_hw]_070317.ipynb
# hw ing.ipynb
# Library_Newspaper.ipynb
# [Mar]_CNN_demo.ipynb
# README
# [SNU]_BDE_080117.ipynb
# [SNU]_BDE_080717_sql_theater_database.ipynb
# [SNU]_BDE_buildingDatabaseTest.ipynb
# [SNU]_BDE_inclass.ipynb
# [SNU]_BDE_PyMySQL.ipynb
# [SNU]_BDMining_081117.ipynb
# [SNU]_BDP_071217_inclass.ipynb
# [SNU]_BDP_071717inclass_Recursion_Tree_Exer.ipynb
# [SNU]_BDP_072117.ipynb
# [SNU]_BDP_072617.ipynb
# [SNU]_BDP_072817_OPP.ipynb
# [SNU]_BDP_073117_Aliasing  Shallow Copy  Deep Copy.ipynb
# [SNU]_BDP_081617.ipynb
# [SNU]_BDP_check_for_homework.ipynb
# [SNU]_BDP_class_072417_14-B.ipynb
# [SNU]_BDP_exercises_072017.ipynb
# [SNU]_BDP_homework_071717.ipynb
# [SNU]_BDP_Lambda and zip .ipynb
# [SNU]_BDProg_071017.ipynb
# ...

# %%
os.system('dir')
# Out:
# 0

# %%
os.system('timeout 5')
# Out:
# 32000

# %%
os.system("sleep 5")
# Out:
# 0

# %%
os.system("sleep 5; print('hi')")
# Out:
# 512

# %%
f = os.popen('dir')

# %%
print(f.read())
# Out:
# [BDE]_0802317.ipynb
# [BDE]_08302017.ipynb
# [BDE]_09062017.ipynb
# [BDP]_170904.ipynb
# call_tkinter.py
# canvas_1.ipynb
# canvas_2.ipynb
# canvas_3.ipynb
# canvas_4.ipynb
# canvas_5.ipynb
# canvas_6.ipynb
# canvas_7.ipynb
# canvas_8.ipynb
# [el_hw]_070317.ipynb
# hw\ ing.ipynb
# Library_Newspaper.ipynb
# [Mar]_CNN_demo.ipynb
# README
# [SNU]_BDE_080117.ipynb
# [SNU]_BDE_080717_sql_theater_database.ipynb
# [SNU]_BDE_buildingDatabaseTest.ipynb
# [SNU]_BDE_inclass.ipynb
# [SNU]_BDE_PyMySQL.ipynb
# [SNU]_BDMining_081117.ipynb
# [SNU]_BDP_071217_inclass.ipynb
# [SNU]_BDP_071717inclass_Recursion_Tree_Exer.ipynb
# [SNU]_BDP_072117.ipynb
# [SNU]_BDP_072617.ipynb
# [SNU]_BDP_072817_OPP.ipynb
# [SNU]_BDP_073117_Aliasing\ \ Shallow\ Copy\ \ Deep\ Copy.ipynb
# [SNU]_BDP_081617.ipynb
# [SNU]_BDP_check_for_homework.ipynb
# [SNU]_BDP_class_072417_14-B.ipynb
# [SNU]_BDP_exercises_072017.ipynb
# [SNU]_BDP_homework_071717.ipynb
# [SNU]_BDP_Lambda\ and\ zip\ .ipynb
# [SNU]_BDProg_071017.ipynb
# ...

# %%
os.path.isfile("[BDE]_0802317.ipynb")
# Out:
# True

# %%
os.path.isdir('/home/snu/mads')
# Out:
# True

# %%
os.path.exists('/home/snu/meme_el')
# Out:
# True

# %%
import time as t
from os import path

def createFile(dest):
    time_form = t.localtime(t.time())
    print("time_form: ", time_form)
    
    filename = "%d_%d_%d.txt" %(time_form[1], timie_form[2], (time_form[0]%100))
    print("file name: ", filename)

# %%
import sys

# %%
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/snu/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
sys.path
# Out:
# ['',
#  '/home/snu/anaconda3/lib/python36.zip',
#  '/home/snu/anaconda3/lib/python3.6',
#  '/home/snu/anaconda3/lib/python3.6/lib-dynload',
#  '/home/snu/anaconda3/lib/python3.6/site-packages',
#  '/home/snu/anaconda3/lib/python3.6/site-packages/Sphinx-1.5.6-py3.6.egg',
#  '/home/snu/anaconda3/lib/python3.6/site-packages/IPython/extensions',
#  '/home/snu/.ipython']
